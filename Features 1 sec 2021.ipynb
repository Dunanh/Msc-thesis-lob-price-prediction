# %%
import pandas as pd
import os

# %%
data_1sec_2021 = pd.read_csv('final_combined_2021_with_time.csv')

# %%
from IPython.display import display, HTML

html_table = data_1sec_2021.head(10).to_html(index=False)
display(HTML(html_table))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Time (sec)</th>
#       <th>Ask Price 1</th>
#       <th>Ask Size 1</th>
#       <th>Bid Price 1</th>
#       <th>Bid Size 1</th>
#       <th>Ask Price 2</th>
#       <th>Ask Size 2</th>
#       <th>Bid Price 2</th>
#       <th>Bid Size 2</th>
#       <th>Event Type</th>
#       <th>Order ID</th>
#       <th>Size</th>
#       <th>Price</th>
#       <th>Direction</th>
#       <th>Mid_Price_1</th>
#       <th>Mid_Price_2</th>
#       <th>Spread_1</th>
#       <th>Spread_2</th>
#       <th>Volume_Mean_1</th>
#       <th>Volume_Mean_2</th>
#       <th>Order_Imbalance_1</th>
#       <th>Order_Imbalance_2</th>
#       <th>VWAP_1</th>
#       <th>VWAP_2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>2021-01-04 09:30:00</td>
#       <td>3753100.0</td>
#       <td>700.0</td>
#       <td>3752800.0</td>
#       <td>100.0</td>
#       <td>3753300.0</td>
#       <td>1500.0</td>
# ...

# %%
data_1sec_2021['Mid_Price_1'] = (data_1sec_2021['Ask Price 1'] + data_1sec_2021['Bid Price 1']) / 2
data_1sec_2021['Mid_Price_2'] = (data_1sec_2021['Ask Price 2'] + data_1sec_2021['Bid Price 2']) / 2
data_1sec_2021['Spread_1'] = data_1sec_2021['Ask Price 1'] - data_1sec_2021['Bid Price 1']
data_1sec_2021['Spread_2'] = data_1sec_2021['Ask Price 2'] - data_1sec_2021['Bid Price 2']
data_1sec_2021['Volume_Mean_1'] = (data_1sec_2021['Ask Size 1'] + data_1sec_2021['Bid Size 1']) / 2
data_1sec_2021['Volume_Mean_2'] = (data_1sec_2021['Ask Size 2'] + data_1sec_2021['Bid Size 2']) / 2
data_1sec_2021['Order_Imbalance_1'] = (data_1sec_2021['Bid Size 1'] - data_1sec_2021['Ask Size 1']) / (data_1sec_2021['Bid Size 1'] + data_1sec_2021['Ask Size 1'])
data_1sec_2021['Order_Imbalance_2'] = (data_1sec_2021['Bid Size 2'] - data_1sec_2021['Ask Size 2']) / (data_1sec_2021['Bid Size 2'] + data_1sec_2021['Ask Size 2'])
data_1sec_2021['VWAP_1'] = (data_1sec_2021['Ask Price 1'] * data_1sec_2021['Ask Size 1'] + 
                             data_1sec_2021['Bid Price 1'] * data_1sec_2021['Bid Size 1']) / \
                            (data_1sec_2021['Ask Size 1'] + data_1sec_2021['Bid Size 1'])

data_1sec_2021['VWAP_2'] = (data_1sec_2021['Ask Price 2'] * data_1sec_2021['Ask Size 2'] + 
                             data_1sec_2021['Bid Price 2'] * data_1sec_2021['Bid Size 2']) / \
                            (data_1sec_2021['Ask Size 2'] + data_1sec_2021['Bid Size 2'])

# %%
data_1sec_2021.to_csv('data_1sec_2021_with_features.csv', index=False)

# %%
print(data_1sec_2021.head())
# Out:
#             Time (sec)  Ask Price 1  Ask Size 1  Bid Price 1  Bid Size 1  \
# 0  2021-01-04 09:30:00    3753100.0       700.0    3752800.0       100.0
# 1  2021-01-04 09:30:01    3753300.0      1792.0    3753000.0       200.0
# 2  2021-01-04 09:30:02    3752800.0        20.0    3752500.0       102.0
# 3  2021-01-04 09:30:03    3753500.0      1000.0    3753200.0       367.0
# 4  2021-01-04 09:30:04    3753600.0       800.0    3753300.0       187.0
#
#    Ask Price 2  Ask Size 2  Bid Price 2  Bid Size 2  Event Type  ...  \
# 0    3753300.0      1500.0    3752600.0       100.0         4.0  ...
# 1    3753400.0       600.0    3752900.0       200.0         3.0  ...
# 2    3752900.0       100.0    3752400.0       100.0         3.0  ...
# 3    3753600.0      1900.0    3753100.0       100.0         1.0  ...
# 4    3753700.0      1100.0    3753200.0       122.0         1.0  ...
#
#    Mid_Price_1  Mid_Price_2  Spread_1  Spread_2  Volume_Mean_1  Volume_Mean_2  \
# ...
