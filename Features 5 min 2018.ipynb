# %%
import pandas as pd
import os
resampled5min2018 = pd.read_csv('resampled_5min_final_2018_corrected.csv')
# print(resampled5min2018.head())

# %%
from IPython.display import display, HTML

html_table = resampled5min2018.head(10).to_html(index=False)
display(HTML(html_table))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Time (sec)</th>
#       <th>Ask Price 1_first</th>
#       <th>Ask Price 1_max</th>
#       <th>Ask Price 1_min</th>
#       <th>Ask Price 1_last</th>
#       <th>Bid Price 1_first</th>
#       <th>Bid Price 1_max</th>
#       <th>Bid Price 1_min</th>
#       <th>Bid Price 1_last</th>
#       <th>Ask Price 2_first</th>
#       <th>Ask Price 2_max</th>
#       <th>Ask Price 2_min</th>
#       <th>Ask Price 2_last</th>
#       <th>Bid Price 2_first</th>
#       <th>Bid Price 2_max</th>
#       <th>Bid Price 2_min</th>
#       <th>Bid Price 2_last</th>
#       <th>Ask Size 1_sum</th>
#       <th>Ask Size 1_mean</th>
#       <th>Bid Size 1_sum</th>
#       <th>Bid Size 1_mean</th>
#       <th>Ask Size 2_sum</th>
#       <th>Ask Size 2_mean</th>
#       <th>Bid Size 2_sum</th>
#       <th>Bid Size 2_mean</th>
#       <th>Price_first</th>
#       <th>Price_max</th>
#       <th>Price_min</th>
# ...

# %% [markdown]
# ##### Mid-price

# %%
# Level 1
resampled5min2018['Mid_Price_1_first'] = (resampled5min2018['Ask Price 1_first'] + resampled5min2018['Bid Price 1_first']) / 2
resampled5min2018['Mid_Price_1_last'] = (resampled5min2018['Ask Price 1_last'] + resampled5min2018['Bid Price 1_last']) / 2
resampled5min2018['Mid_Price_1_min'] = (resampled5min2018['Ask Price 1_min'] + resampled5min2018['Bid Price 1_min']) / 2
resampled5min2018['Mid_Price_1_max'] = (resampled5min2018['Ask Price 1_max'] + resampled5min2018['Bid Price 1_max']) / 2

# Level 2
resampled5min2018['Mid_Price_2_first'] = (resampled5min2018['Ask Price 2_first'] + resampled5min2018['Bid Price 2_first']) / 2
resampled5min2018['Mid_Price_2_last'] = (resampled5min2018['Ask Price 2_last'] + resampled5min2018['Bid Price 2_last']) / 2
resampled5min2018['Mid_Price_2_min'] = (resampled5min2018['Ask Price 2_min'] + resampled5min2018['Bid Price 2_min']) / 2
resampled5min2018['Mid_Price_2_max'] = (resampled5min2018['Ask Price 2_max'] + resampled5min2018['Bid Price 2_max']) / 2

# %% [markdown]
# ##### Spread

# %%
# Level 1
resampled5min2018['Spread_1_first'] = resampled5min2018['Ask Price 1_first'] - resampled5min2018['Bid Price 1_first']
resampled5min2018['Spread_1_last'] = resampled5min2018['Ask Price 1_last'] - resampled5min2018['Bid Price 1_last']
resampled5min2018['Spread_1_min'] = resampled5min2018['Ask Price 1_min'] - resampled5min2018['Bid Price 1_min']
resampled5min2018['Spread_1_max'] = resampled5min2018['Ask Price 1_max'] - resampled5min2018['Bid Price 1_max']

# Level 2
resampled5min2018['Spread_2_first'] = resampled5min2018['Ask Price 2_first'] - resampled5min2018['Bid Price 2_first']
resampled5min2018['Spread_2_last'] = resampled5min2018['Ask Price 2_last'] - resampled5min2018['Bid Price 2_last']
resampled5min2018['Spread_2_min'] = resampled5min2018['Ask Price 2_min'] - resampled5min2018['Bid Price 2_min']
resampled5min2018['Spread_2_max'] = resampled5min2018['Ask Price 2_max'] - resampled5min2018['Bid Price 2_max']

# %% [markdown]
# ##### Price Means

# %%
# Level 1
resampled5min2018['Price_Mean_1_first'] = (resampled5min2018['Ask Price 1_first'] + resampled5min2018['Bid Price 1_first']) / 2
resampled5min2018['Price_Mean_1_last'] = (resampled5min2018['Ask Price 1_last'] + resampled5min2018['Bid Price 1_last']) / 2
resampled5min2018['Price_Mean_1_min'] = (resampled5min2018['Ask Price 1_min'] + resampled5min2018['Bid Price 1_min']) / 2
resampled5min2018['Price_Mean_1_max'] = (resampled5min2018['Ask Price 1_max'] + resampled5min2018['Bid Price 1_max']) / 2

# Level 2
resampled5min2018['Price_Mean_2_first'] = (resampled5min2018['Ask Price 2_first'] + resampled5min2018['Bid Price 2_first']) / 2
resampled5min2018['Price_Mean_2_last'] = (resampled5min2018['Ask Price 2_last'] + resampled5min2018['Bid Price 2_last']) / 2
resampled5min2018['Price_Mean_2_min'] = (resampled5min2018['Ask Price 2_min'] + resampled5min2018['Bid Price 2_min']) / 2
resampled5min2018['Price_Mean_2_max'] = (resampled5min2018['Ask Price 2_max'] + resampled5min2018['Bid Price 2_max']) / 2

# %% [markdown]
# ##### Volume Means

# %%
# Level 1
resampled5min2018['Volume_Mean_1'] = (resampled5min2018['Ask Size 1_mean'] + resampled5min2018['Bid Size 1_mean']) / 2

# Level 2
resampled5min2018['Volume_Mean_2'] = (resampled5min2018['Ask Size 2_mean'] + resampled5min2018['Bid Size 2_mean']) / 2

# %% [markdown]
# ##### Order Imbalance

# %%
# Level 1
resampled5min2018['Order_Imbalance_1'] = (resampled5min2018['Bid Size 1_sum'] - resampled5min2018['Ask Size 1_sum']) / (resampled5min2018['Bid Size 1_sum'] + resampled5min2018['Ask Size 1_sum'])

# Level 2
resampled5min2018['Order_Imbalance_2'] = (resampled5min2018['Bid Size 2_sum'] - resampled5min2018['Ask Size 2_sum']) / (resampled5min2018['Bid Size 2_sum'] + resampled5min2018['Ask Size 2_sum'])

# %% [markdown]
# ##### Volume Weighted Average Price (VWAP)

# %%
# Level 1
resampled5min2018['VWAP_1'] = (resampled5min2018['Ask Price 1_last'] * resampled5min2018['Ask Size 1_sum'] + 
                               resampled5min2018['Bid Price 1_last'] * resampled5min2018['Bid Size 1_sum']) / \
                              (resampled5min2018['Ask Size 1_sum'] + resampled5min2018['Bid Size 1_sum'])

# Level 2
resampled5min2018['VWAP_2'] = (resampled5min2018['Ask Price 2_last'] * resampled5min2018['Ask Size 2_sum'] + 
                               resampled5min2018['Bid Price 2_last'] * resampled5min2018['Bid Size 2_sum']) / \
                              (resampled5min2018['Ask Size 2_sum'] + resampled5min2018['Bid Size 2_sum'])

# %%
resampled5min2018.to_csv('resampled_5min_2018_with_features.csv', index=False)
print(resampled5min2018.head())
# Out:
#             Time (sec)  Ask Price 1_first  Ask Price 1_max  Ask Price 1_min  \
# 0  2018-01-02 09:30:00          2678500.0        2678900.0        2674700.0
# 1  2018-01-02 09:35:00          2674800.0        2678200.0        2674000.0
# 2  2018-01-02 09:40:00          2678000.0        2679300.0        2677800.0
# 3  2018-01-02 09:45:00          2678200.0        2678400.0        2676800.0
# 4  2018-01-02 09:50:00          2676900.0        2677600.0        2676100.0
#
#    Ask Price 1_last  Bid Price 1_first  Bid Price 1_max  Bid Price 1_min  \
# 0         2674700.0          2678400.0        2678700.0        2674600.0
# 1         2678000.0          2674700.0        2678000.0        2673900.0
# 2         2678300.0          2677900.0        2679200.0        2677700.0
# 3         2676900.0          2678100.0        2678300.0        2676700.0
# 4         2677300.0          2676700.0        2677500.0        2676000.0
#
#    Bid Price 1_last  Ask Price 2_first  ...  Price_Mean_2_first  \
# ...
