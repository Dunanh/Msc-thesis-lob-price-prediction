# %%
import pandas as pd
import os
resampled5min2019 = pd.read_csv('resampled_5min_final_2019_corrected.csv')
# print(resampled5min2019.head())

# %%
from IPython.display import display, HTML

html_table = resampled5min2019.head(10).to_html(index=False)
display(HTML(html_table))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Time (sec)</th>
#       <th>Ask Price 1_first</th>
#       <th>Ask Price 1_max</th>
#       <th>Ask Price 1_min</th>
#       <th>Ask Price 1_last</th>
#       <th>Bid Price 1_first</th>
#       <th>Bid Price 1_max</th>
#       <th>Bid Price 1_min</th>
#       <th>Bid Price 1_last</th>
#       <th>Ask Price 2_first</th>
#       <th>Ask Price 2_max</th>
#       <th>Ask Price 2_min</th>
#       <th>Ask Price 2_last</th>
#       <th>Bid Price 2_first</th>
#       <th>Bid Price 2_max</th>
#       <th>Bid Price 2_min</th>
#       <th>Bid Price 2_last</th>
#       <th>Ask Size 1_sum</th>
#       <th>Ask Size 1_mean</th>
#       <th>Bid Size 1_sum</th>
#       <th>Bid Size 1_mean</th>
#       <th>Ask Size 2_sum</th>
#       <th>Ask Size 2_mean</th>
#       <th>Bid Size 2_sum</th>
#       <th>Bid Size 2_mean</th>
#       <th>Price_first</th>
#       <th>Price_max</th>
#       <th>Price_min</th>
# ...

# %% [markdown]
# ##### Mid-price

# %%
# Level 1
resampled5min2019['Mid_Price_1_first'] = (resampled5min2019['Ask Price 1_first'] + resampled5min2019['Bid Price 1_first']) / 2
resampled5min2019['Mid_Price_1_last'] = (resampled5min2019['Ask Price 1_last'] + resampled5min2019['Bid Price 1_last']) / 2
resampled5min2019['Mid_Price_1_min'] = (resampled5min2019['Ask Price 1_min'] + resampled5min2019['Bid Price 1_min']) / 2
resampled5min2019['Mid_Price_1_max'] = (resampled5min2019['Ask Price 1_max'] + resampled5min2019['Bid Price 1_max']) / 2

# Level 2
resampled5min2019['Mid_Price_2_first'] = (resampled5min2019['Ask Price 2_first'] + resampled5min2019['Bid Price 2_first']) / 2
resampled5min2019['Mid_Price_2_last'] = (resampled5min2019['Ask Price 2_last'] + resampled5min2019['Bid Price 2_last']) / 2
resampled5min2019['Mid_Price_2_min'] = (resampled5min2019['Ask Price 2_min'] + resampled5min2019['Bid Price 2_min']) / 2
resampled5min2019['Mid_Price_2_max'] = (resampled5min2019['Ask Price 2_max'] + resampled5min2019['Bid Price 2_max']) / 2

# %% [markdown]
# ##### Spread

# %%
# Level 1
resampled5min2019['Spread_1_first'] = resampled5min2019['Ask Price 1_first'] - resampled5min2019['Bid Price 1_first']
resampled5min2019['Spread_1_last'] = resampled5min2019['Ask Price 1_last'] - resampled5min2019['Bid Price 1_last']
resampled5min2019['Spread_1_min'] = resampled5min2019['Ask Price 1_min'] - resampled5min2019['Bid Price 1_min']
resampled5min2019['Spread_1_max'] = resampled5min2019['Ask Price 1_max'] - resampled5min2019['Bid Price 1_max']

# Level 2
resampled5min2019['Spread_2_first'] = resampled5min2019['Ask Price 2_first'] - resampled5min2019['Bid Price 2_first']
resampled5min2019['Spread_2_last'] = resampled5min2019['Ask Price 2_last'] - resampled5min2019['Bid Price 2_last']
resampled5min2019['Spread_2_min'] = resampled5min2019['Ask Price 2_min'] - resampled5min2019['Bid Price 2_min']
resampled5min2019['Spread_2_max'] = resampled5min2019['Ask Price 2_max'] - resampled5min2019['Bid Price 2_max']

# %% [markdown]
# ##### Price Means

# %%
# Level 1
resampled5min2019['Price_Mean_1_first'] = (resampled5min2019['Ask Price 1_first'] + resampled5min2019['Bid Price 1_first']) / 2
resampled5min2019['Price_Mean_1_last'] = (resampled5min2019['Ask Price 1_last'] + resampled5min2019['Bid Price 1_last']) / 2
resampled5min2019['Price_Mean_1_min'] = (resampled5min2019['Ask Price 1_min'] + resampled5min2019['Bid Price 1_min']) / 2
resampled5min2019['Price_Mean_1_max'] = (resampled5min2019['Ask Price 1_max'] + resampled5min2019['Bid Price 1_max']) / 2

# Level 2
resampled5min2019['Price_Mean_2_first'] = (resampled5min2019['Ask Price 2_first'] + resampled5min2019['Bid Price 2_first']) / 2
resampled5min2019['Price_Mean_2_last'] = (resampled5min2019['Ask Price 2_last'] + resampled5min2019['Bid Price 2_last']) / 2
resampled5min2019['Price_Mean_2_min'] = (resampled5min2019['Ask Price 2_min'] + resampled5min2019['Bid Price 2_min']) / 2
resampled5min2019['Price_Mean_2_max'] = (resampled5min2019['Ask Price 2_max'] + resampled5min2019['Bid Price 2_max']) / 2

# %% [markdown]
# ##### Volume Means

# %%
# Level 1
resampled5min2019['Volume_Mean_1'] = (resampled5min2019['Ask Size 1_mean'] + resampled5min2019['Bid Size 1_mean']) / 2

# Level 2
resampled5min2019['Volume_Mean_2'] = (resampled5min2019['Ask Size 2_mean'] + resampled5min2019['Bid Size 2_mean']) / 2

# %% [markdown]
# ##### Order Imbalance

# %%
# Level 1
resampled5min2019['Order_Imbalance_1'] = (resampled5min2019['Bid Size 1_sum'] - resampled5min2019['Ask Size 1_sum']) / (resampled5min2019['Bid Size 1_sum'] + resampled5min2019['Ask Size 1_sum'])

# Level 2
resampled5min2019['Order_Imbalance_2'] = (resampled5min2019['Bid Size 2_sum'] - resampled5min2019['Ask Size 2_sum']) / (resampled5min2019['Bid Size 2_sum'] + resampled5min2019['Ask Size 2_sum'])

# %% [markdown]
# ##### Volume Weighted Average Price (VWAP)

# %%
# Level 1
resampled5min2019['VWAP_1'] = (resampled5min2019['Ask Price 1_last'] * resampled5min2019['Ask Size 1_sum'] + 
                               resampled5min2019['Bid Price 1_last'] * resampled5min2019['Bid Size 1_sum']) / \
                              (resampled5min2019['Ask Size 1_sum'] + resampled5min2019['Bid Size 1_sum'])

# Level 2
resampled5min2019['VWAP_2'] = (resampled5min2019['Ask Price 2_last'] * resampled5min2019['Ask Size 2_sum'] + 
                               resampled5min2019['Bid Price 2_last'] * resampled5min2019['Bid Size 2_sum']) / \
                              (resampled5min2019['Ask Size 2_sum'] + resampled5min2019['Bid Size 2_sum'])

# %%
resampled5min2019.to_csv('resampled_5min_2019_with_features.csv', index=False)
print(resampled5min2019.head())
# Out:
#             Time (sec)  Ask Price 1_first  Ask Price 1_max  Ask Price 1_min  \
# 0  2019-01-02 09:30:00          2460200.0        2466000.0        2460100.0
# 1  2019-01-02 09:35:00          2463000.0        2467400.0        2459700.0
# 2  2019-01-02 09:40:00          2465300.0        2469200.0        2461500.0
# 3  2019-01-02 09:45:00          2469100.0        2473200.0        2468900.0
# 4  2019-01-02 09:50:00          2471300.0        2474000.0        2467400.0
#
#    Ask Price 1_last  Bid Price 1_first  Bid Price 1_max  Bid Price 1_min  \
# 0         2463200.0          2459600.0        2465800.0        2459600.0
# 1         2465200.0          2462900.0        2467200.0        2459600.0
# 2         2469000.0          2465200.0        2469100.0        2461400.0
# 3         2471600.0          2469000.0        2473100.0        2468800.0
# 4         2469300.0          2471200.0        2473900.0        2467300.0
#
# ...
