# %%
import pandas as pd
import os
resampled5min2022 = pd.read_csv('resampled_5min_final_2022_corrected.csv')

# %%
from IPython.display import display, HTML

html_table = resampled5min2022.head(10).to_html(index=False)
display(HTML(html_table))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Time (sec)</th>
#       <th>Ask Price 1_first</th>
#       <th>Ask Price 1_max</th>
#       <th>Ask Price 1_min</th>
#       <th>Ask Price 1_last</th>
#       <th>Bid Price 1_first</th>
#       <th>Bid Price 1_max</th>
#       <th>Bid Price 1_min</th>
#       <th>Bid Price 1_last</th>
#       <th>Ask Price 2_first</th>
#       <th>Ask Price 2_max</th>
#       <th>Ask Price 2_min</th>
#       <th>Ask Price 2_last</th>
#       <th>Bid Price 2_first</th>
#       <th>Bid Price 2_max</th>
#       <th>Bid Price 2_min</th>
#       <th>Bid Price 2_last</th>
#       <th>Ask Size 1_sum</th>
#       <th>Ask Size 1_mean</th>
#       <th>Bid Size 1_sum</th>
#       <th>Bid Size 1_mean</th>
#       <th>Ask Size 2_sum</th>
#       <th>Ask Size 2_mean</th>
#       <th>Bid Size 2_sum</th>
#       <th>Bid Size 2_mean</th>
#       <th>Price_first</th>
#       <th>Price_max</th>
#       <th>Price_min</th>
# ...

# %% [markdown]
# ##### Mid-price

# %%
# Calculate Mid-Price
# Level 1
resampled5min2022['Mid_Price_1_first'] = (resampled5min2022['Ask Price 1_first'] + resampled5min2022['Bid Price 1_first']) / 2
resampled5min2022['Mid_Price_1_last'] = (resampled5min2022['Ask Price 1_last'] + resampled5min2022['Bid Price 1_last']) / 2
resampled5min2022['Mid_Price_1_min'] = (resampled5min2022['Ask Price 1_min'] + resampled5min2022['Bid Price 1_min']) / 2
resampled5min2022['Mid_Price_1_max'] = (resampled5min2022['Ask Price 1_max'] + resampled5min2022['Bid Price 1_max']) / 2

# Level 2
resampled5min2022['Mid_Price_2_first'] = (resampled5min2022['Ask Price 2_first'] + resampled5min2022['Bid Price 2_first']) / 2
resampled5min2022['Mid_Price_2_last'] = (resampled5min2022['Ask Price 2_last'] + resampled5min2022['Bid Price 2_last']) / 2
resampled5min2022['Mid_Price_2_min'] = (resampled5min2022['Ask Price 2_min'] + resampled5min2022['Bid Price 2_min']) / 2
resampled5min2022['Mid_Price_2_max'] = (resampled5min2022['Ask Price 2_max'] + resampled5min2022['Bid Price 2_max']) / 2

# %% [markdown]
# ##### Spread

# %%
# Level 1
resampled5min2022['Spread_1_first'] = resampled5min2022['Ask Price 1_first'] - resampled5min2022['Bid Price 1_first']
resampled5min2022['Spread_1_last'] = resampled5min2022['Ask Price 1_last'] - resampled5min2022['Bid Price 1_last']
resampled5min2022['Spread_1_min'] = resampled5min2022['Ask Price 1_min'] - resampled5min2022['Bid Price 1_min']
resampled5min2022['Spread_1_max'] = resampled5min2022['Ask Price 1_max'] - resampled5min2022['Bid Price 1_max']

# Level 2
resampled5min2022['Spread_2_first'] = resampled5min2022['Ask Price 2_first'] - resampled5min2022['Bid Price 2_first']
resampled5min2022['Spread_2_last'] = resampled5min2022['Ask Price 2_last'] - resampled5min2022['Bid Price 2_last']
resampled5min2022['Spread_2_min'] = resampled5min2022['Ask Price 2_min'] - resampled5min2022['Bid Price 2_min']
resampled5min2022['Spread_2_max'] = resampled5min2022['Ask Price 2_max'] - resampled5min2022['Bid Price 2_max']

# %% [markdown]
# ##### Price Means

# %%
# Level 1
resampled5min2022['Price_Mean_1_first'] = (resampled5min2022['Ask Price 1_first'] + resampled5min2022['Bid Price 1_first']) / 2
resampled5min2022['Price_Mean_1_last'] = (resampled5min2022['Ask Price 1_last'] + resampled5min2022['Bid Price 1_last']) / 2
resampled5min2022['Price_Mean_1_min'] = (resampled5min2022['Ask Price 1_min'] + resampled5min2022['Bid Price 1_min']) / 2
resampled5min2022['Price_Mean_1_max'] = (resampled5min2022['Ask Price 1_max'] + resampled5min2022['Bid Price 1_max']) / 2

# Level 2
resampled5min2022['Price_Mean_2_first'] = (resampled5min2022['Ask Price 2_first'] + resampled5min2022['Bid Price 2_first']) / 2
resampled5min2022['Price_Mean_2_last'] = (resampled5min2022['Ask Price 2_last'] + resampled5min2022['Bid Price 2_last']) / 2
resampled5min2022['Price_Mean_2_min'] = (resampled5min2022['Ask Price 2_min'] + resampled5min2022['Bid Price 2_min']) / 2
resampled5min2022['Price_Mean_2_max'] = (resampled5min2022['Ask Price 2_max'] + resampled5min2022['Bid Price 2_max']) / 2

# %% [markdown]
# ##### Volume Means

# %%
# Level 1
resampled5min2022['Volume_Mean_1'] = (resampled5min2022['Ask Size 1_mean'] + resampled5min2022['Bid Size 1_mean']) / 2

# Level 2
resampled5min2022['Volume_Mean_2'] = (resampled5min2022['Ask Size 2_mean'] + resampled5min2022['Bid Size 2_mean']) / 2

# %% [markdown]
# ##### Order Imbalance

# %%
# Level 1
resampled5min2022['Order_Imbalance_1'] = (resampled5min2022['Bid Size 1_sum'] - resampled5min2022['Ask Size 1_sum']) / (resampled5min2022['Bid Size 1_sum'] + resampled5min2022['Ask Size 1_sum'])

# Level 2
resampled5min2022['Order_Imbalance_2'] = (resampled5min2022['Bid Size 2_sum'] - resampled5min2022['Ask Size 2_sum']) / (resampled5min2022['Bid Size 2_sum'] + resampled5min2022['Ask Size 2_sum'])

# %% [markdown]
# ##### Volume Weighted Average Price (VWAP)

# %%
# Level 1
resampled5min2022['VWAP_1'] = (resampled5min2022['Ask Price 1_last'] * resampled5min2022['Ask Size 1_sum'] + 
                               resampled5min2022['Bid Price 1_last'] * resampled5min2022['Bid Size 1_sum']) / \
                              (resampled5min2022['Ask Size 1_sum'] + resampled5min2022['Bid Size 1_sum'])

# Level 2
resampled5min2022['VWAP_2'] = (resampled5min2022['Ask Price 2_last'] * resampled5min2022['Ask Size 2_sum'] + 
                               resampled5min2022['Bid Price 2_last'] * resampled5min2022['Bid Size 2_sum']) / \
                              (resampled5min2022['Ask Size 2_sum'] + resampled5min2022['Bid Size 2_sum'])

# %%
resampled5min2022.to_csv('resampled_5min_2022_with_features.csv', index=False)
print(resampled5min2022.head())
# Out:
#             Time (sec)  Ask Price 1_first  Ask Price 1_max  Ask Price 1_min  \
# 0  2022-01-03 09:30:00          4763400.0        4771700.0        4763000.0
# 1  2022-01-03 09:35:00          4770800.0        4777200.0        4769200.0
# 2  2022-01-03 09:40:00          4773000.0        4774500.0        4770300.0
# 3  2022-01-03 09:45:00          4771800.0        4772300.0        4745800.0
# 4  2022-01-03 09:50:00          4749100.0        4754800.0        4738700.0
#
#    Ask Price 1_last  Bid Price 1_first  Bid Price 1_max  Bid Price 1_min  \
# 0         4771200.0          4763000.0        4771600.0        4762700.0
# 1         4772200.0          4770700.0        4777000.0        4769000.0
# 2         4770800.0          4772700.0        4774300.0        4770200.0
# 3         4748200.0          4771600.0        4772100.0        4745600.0
# 4         4750300.0          4749000.0        4754500.0        4738600.0
#
#    Bid Price 1_last  Ask Price 2_first  ...  Price_Mean_2_first  \
# ...
