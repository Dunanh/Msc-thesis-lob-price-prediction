# %%
import pandas as pd
import os
resampled5min2023 = pd.read_csv('resampled_5min_final_2023_corrected.csv')

# %%
from IPython.display import display, HTML

html_table = resampled5min2023.head(10).to_html(index=False)
display(HTML(html_table))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Time (sec)</th>
#       <th>Ask Price 1_first</th>
#       <th>Ask Price 1_max</th>
#       <th>Ask Price 1_min</th>
#       <th>Ask Price 1_last</th>
#       <th>Bid Price 1_first</th>
#       <th>Bid Price 1_max</th>
#       <th>Bid Price 1_min</th>
#       <th>Bid Price 1_last</th>
#       <th>Ask Price 2_first</th>
#       <th>Ask Price 2_max</th>
#       <th>Ask Price 2_min</th>
#       <th>Ask Price 2_last</th>
#       <th>Bid Price 2_first</th>
#       <th>Bid Price 2_max</th>
#       <th>Bid Price 2_min</th>
#       <th>Bid Price 2_last</th>
#       <th>Ask Size 1_sum</th>
#       <th>Ask Size 1_mean</th>
#       <th>Bid Size 1_sum</th>
#       <th>Bid Size 1_mean</th>
#       <th>Ask Size 2_sum</th>
#       <th>Ask Size 2_mean</th>
#       <th>Bid Size 2_sum</th>
#       <th>Bid Size 2_mean</th>
#       <th>Price_first</th>
#       <th>Price_max</th>
#       <th>Price_min</th>
# ...

# %% [markdown]
# ##### Mid-price

# %%
# Level 1
resampled5min2023['Mid_Price_1_first'] = (resampled5min2023['Ask Price 1_first'] + resampled5min2023['Bid Price 1_first']) / 2
resampled5min2023['Mid_Price_1_last'] = (resampled5min2023['Ask Price 1_last'] + resampled5min2023['Bid Price 1_last']) / 2
resampled5min2023['Mid_Price_1_min'] = (resampled5min2023['Ask Price 1_min'] + resampled5min2023['Bid Price 1_min']) / 2
resampled5min2023['Mid_Price_1_max'] = (resampled5min2023['Ask Price 1_max'] + resampled5min2023['Bid Price 1_max']) / 2

# Level 2
resampled5min2023['Mid_Price_2_first'] = (resampled5min2023['Ask Price 2_first'] + resampled5min2023['Bid Price 2_first']) / 2
resampled5min2023['Mid_Price_2_last'] = (resampled5min2023['Ask Price 2_last'] + resampled5min2023['Bid Price 2_last']) / 2
resampled5min2023['Mid_Price_2_min'] = (resampled5min2023['Ask Price 2_min'] + resampled5min2023['Bid Price 2_min']) / 2
resampled5min2023['Mid_Price_2_max'] = (resampled5min2023['Ask Price 2_max'] + resampled5min2023['Bid Price 2_max']) / 2

# %% [markdown]
# ##### Spread

# %%
# Level 1
resampled5min2023['Spread_1_first'] = resampled5min2023['Ask Price 1_first'] - resampled5min2023['Bid Price 1_first']
resampled5min2023['Spread_1_last'] = resampled5min2023['Ask Price 1_last'] - resampled5min2023['Bid Price 1_last']
resampled5min2023['Spread_1_min'] = resampled5min2023['Ask Price 1_min'] - resampled5min2023['Bid Price 1_min']
resampled5min2023['Spread_1_max'] = resampled5min2023['Ask Price 1_max'] - resampled5min2023['Bid Price 1_max']
# Level 2
resampled5min2023['Spread_2_first'] = resampled5min2023['Ask Price 2_first'] - resampled5min2023['Bid Price 2_first']
resampled5min2023['Spread_2_last'] = resampled5min2023['Ask Price 2_last'] - resampled5min2023['Bid Price 2_last']
resampled5min2023['Spread_2_min'] = resampled5min2023['Ask Price 2_min'] - resampled5min2023['Bid Price 2_min']
resampled5min2023['Spread_2_max'] = resampled5min2023['Ask Price 2_max'] - resampled5min2023['Bid Price 2_max']

# %% [markdown]
# ##### Price Means

# %%
# Level 1
resampled5min2023['Price_Mean_1_first'] = (resampled5min2023['Ask Price 1_first'] + resampled5min2023['Bid Price 1_first']) / 2
resampled5min2023['Price_Mean_1_last'] = (resampled5min2023['Ask Price 1_last'] + resampled5min2023['Bid Price 1_last']) / 2
resampled5min2023['Price_Mean_1_min'] = (resampled5min2023['Ask Price 1_min'] + resampled5min2023['Bid Price 1_min']) / 2
resampled5min2023['Price_Mean_1_max'] = (resampled5min2023['Ask Price 1_max'] + resampled5min2023['Bid Price 1_max']) / 2

# Level 2
resampled5min2023['Price_Mean_2_first'] = (resampled5min2023['Ask Price 2_first'] + resampled5min2023['Bid Price 2_first']) / 2
resampled5min2023['Price_Mean_2_last'] = (resampled5min2023['Ask Price 2_last'] + resampled5min2023['Bid Price 2_last']) / 2
resampled5min2023['Price_Mean_2_min'] = (resampled5min2023['Ask Price 2_min'] + resampled5min2023['Bid Price 2_min']) / 2
resampled5min2023['Price_Mean_2_max'] = (resampled5min2023['Ask Price 2_max'] + resampled5min2023['Bid Price 2_max']) / 2

# %% [markdown]
# ##### Volume Means

# %%
# Level 1
resampled5min2023['Volume_Mean_1'] = (resampled5min2023['Ask Size 1_mean'] + resampled5min2023['Bid Size 1_mean']) / 2

# Level 2
resampled5min2023['Volume_Mean_2'] = (resampled5min2023['Ask Size 2_mean'] + resampled5min2023['Bid Size 2_mean']) / 2

# %% [markdown]
# ##### Order Imbalance

# %%
# Level 1
resampled5min2023['Order_Imbalance_1'] = (resampled5min2023['Bid Size 1_sum'] - resampled5min2023['Ask Size 1_sum']) / (resampled5min2023['Bid Size 1_sum'] + resampled5min2023['Ask Size 1_sum'])

# Level 2
resampled5min2023['Order_Imbalance_2'] = (resampled5min2023['Bid Size 2_sum'] - resampled5min2023['Ask Size 2_sum']) / (resampled5min2023['Bid Size 2_sum'] + resampled5min2023['Ask Size 2_sum'])

# %% [markdown]
# ##### Volume Weighted Average Price (VWAP)

# %%
# Calculate VWAP
# Level 1
resampled5min2023['VWAP_1'] = (resampled5min2023['Ask Price 1_last'] * resampled5min2023['Ask Size 1_sum'] + 
                               resampled5min2023['Bid Price 1_last'] * resampled5min2023['Bid Size 1_sum']) / \
                              (resampled5min2023['Ask Size 1_sum'] + resampled5min2023['Bid Size 1_sum'])

# Level 2
resampled5min2023['VWAP_2'] = (resampled5min2023['Ask Price 2_last'] * resampled5min2023['Ask Size 2_sum'] + 
                               resampled5min2023['Bid Price 2_last'] * resampled5min2023['Bid Size 2_sum']) / \
                              (resampled5min2023['Ask Size 2_sum'] + resampled5min2023['Bid Size 2_sum'])

# %%
resampled5min2023.to_csv('resampled_5min_2023_with_features.csv', index=False)
print(resampled5min2023.head())
# Out:
#             Time (sec)  Ask Price 1_first  Ask Price 1_max  Ask Price 1_min  \
# 0  2023-01-03 09:30:00          3844100.0        3851300.0        3836200.0
# 1  2023-01-03 09:35:00          3845400.0        3854600.0        3843500.0
# 2  2023-01-03 09:40:00          3854100.0        3864000.0        3852100.0
# 3  2023-01-03 09:45:00          3852900.0        3853700.0        3830600.0
# 4  2023-01-03 09:50:00          3835100.0        3839600.0        3825500.0
#
#    Ask Price 1_last  Bid Price 1_first  Bid Price 1_max  Bid Price 1_min  \
# 0         3845000.0          3843400.0        3851100.0        3836000.0
# 1         3853400.0          3844900.0        3854300.0        3843200.0
# 2         3852600.0          3853700.0        3863600.0        3851600.0
# 3         3835200.0          3852600.0        3853300.0        3830400.0
# 4         3828300.0          3834900.0        3839300.0        3825100.0
#
#    Bid Price 1_last  Ask Price 2_first  ...  Price_Mean_2_first  \
# ...
