# %%
import pandas as pd
import os
resampled5min2020 = pd.read_csv('resampled_5min_final_2020_corrected.csv')

# %%
from IPython.display import display, HTML

html_table = resampled5min2020.head(10).to_html(index=False)
display(HTML(html_table))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Time (sec)</th>
#       <th>Ask Price 1_first</th>
#       <th>Ask Price 1_max</th>
#       <th>Ask Price 1_min</th>
#       <th>Ask Price 1_last</th>
#       <th>Bid Price 1_first</th>
#       <th>Bid Price 1_max</th>
#       <th>Bid Price 1_min</th>
#       <th>Bid Price 1_last</th>
#       <th>Ask Price 2_first</th>
#       <th>Ask Price 2_max</th>
#       <th>Ask Price 2_min</th>
#       <th>Ask Price 2_last</th>
#       <th>Bid Price 2_first</th>
#       <th>Bid Price 2_max</th>
#       <th>Bid Price 2_min</th>
#       <th>Bid Price 2_last</th>
#       <th>Ask Size 1_sum</th>
#       <th>Ask Size 1_mean</th>
#       <th>Bid Size 1_sum</th>
#       <th>Bid Size 1_mean</th>
#       <th>Ask Size 2_sum</th>
#       <th>Ask Size 2_mean</th>
#       <th>Bid Size 2_sum</th>
#       <th>Bid Size 2_mean</th>
#       <th>Price_first</th>
#       <th>Price_max</th>
#       <th>Price_min</th>
# ...

# %% [markdown]
# ##### Mid-price

# %%
# Calculate Mid-Price
# Level 1
resampled5min2020['Mid_Price_1_first'] = (resampled5min2020['Ask Price 1_first'] + resampled5min2020['Bid Price 1_first']) / 2
resampled5min2020['Mid_Price_1_last'] = (resampled5min2020['Ask Price 1_last'] + resampled5min2020['Bid Price 1_last']) / 2
resampled5min2020['Mid_Price_1_min'] = (resampled5min2020['Ask Price 1_min'] + resampled5min2020['Bid Price 1_min']) / 2
resampled5min2020['Mid_Price_1_max'] = (resampled5min2020['Ask Price 1_max'] + resampled5min2020['Bid Price 1_max']) / 2

# Level 2
resampled5min2020['Mid_Price_2_first'] = (resampled5min2020['Ask Price 2_first'] + resampled5min2020['Bid Price 2_first']) / 2
resampled5min2020['Mid_Price_2_last'] = (resampled5min2020['Ask Price 2_last'] + resampled5min2020['Bid Price 2_last']) / 2
resampled5min2020['Mid_Price_2_min'] = (resampled5min2020['Ask Price 2_min'] + resampled5min2020['Bid Price 2_min']) / 2
resampled5min2020['Mid_Price_2_max'] = (resampled5min2020['Ask Price 2_max'] + resampled5min2020['Bid Price 2_max']) / 2

# %% [markdown]
# ##### Spread

# %%
# Level 1
resampled5min2020['Spread_1_first'] = resampled5min2020['Ask Price 1_first'] - resampled5min2020['Bid Price 1_first']
resampled5min2020['Spread_1_last'] = resampled5min2020['Ask Price 1_last'] - resampled5min2020['Bid Price 1_last']
resampled5min2020['Spread_1_min'] = resampled5min2020['Ask Price 1_min'] - resampled5min2020['Bid Price 1_min']
resampled5min2020['Spread_1_max'] = resampled5min2020['Ask Price 1_max'] - resampled5min2020['Bid Price 1_max']

# Level 2
resampled5min2020['Spread_2_first'] = resampled5min2020['Ask Price 2_first'] - resampled5min2020['Bid Price 2_first']
resampled5min2020['Spread_2_last'] = resampled5min2020['Ask Price 2_last'] - resampled5min2020['Bid Price 2_last']
resampled5min2020['Spread_2_min'] = resampled5min2020['Ask Price 2_min'] - resampled5min2020['Bid Price 2_min']
resampled5min2020['Spread_2_max'] = resampled5min2020['Ask Price 2_max'] - resampled5min2020['Bid Price 2_max']

# %% [markdown]
# ##### Price Means

# %%
# Level 1
resampled5min2020['Price_Mean_1_first'] = (resampled5min2020['Ask Price 1_first'] + resampled5min2020['Bid Price 1_first']) / 2
resampled5min2020['Price_Mean_1_last'] = (resampled5min2020['Ask Price 1_last'] + resampled5min2020['Bid Price 1_last']) / 2
resampled5min2020['Price_Mean_1_min'] = (resampled5min2020['Ask Price 1_min'] + resampled5min2020['Bid Price 1_min']) / 2
resampled5min2020['Price_Mean_1_max'] = (resampled5min2020['Ask Price 1_max'] + resampled5min2020['Bid Price 1_max']) / 2

# Level 2
resampled5min2020['Price_Mean_2_first'] = (resampled5min2020['Ask Price 2_first'] + resampled5min2020['Bid Price 2_first']) / 2
resampled5min2020['Price_Mean_2_last'] = (resampled5min2020['Ask Price 2_last'] + resampled5min2020['Bid Price 2_last']) / 2
resampled5min2020['Price_Mean_2_min'] = (resampled5min2020['Ask Price 2_min'] + resampled5min2020['Bid Price 2_min']) / 2
resampled5min2020['Price_Mean_2_max'] = (resampled5min2020['Ask Price 2_max'] + resampled5min2020['Bid Price 2_max']) / 2

# %% [markdown]
# ##### Volume Means

# %%
# Level 1
resampled5min2020['Volume_Mean_1'] = (resampled5min2020['Ask Size 1_mean'] + resampled5min2020['Bid Size 1_mean']) / 2

# Level 2
resampled5min2020['Volume_Mean_2'] = (resampled5min2020['Ask Size 2_mean'] + resampled5min2020['Bid Size 2_mean']) / 2

# %% [markdown]
# ##### Order Imbalance

# %%
# Level 1
resampled5min2020['Order_Imbalance_1'] = (resampled5min2020['Bid Size 1_sum'] - resampled5min2020['Ask Size 1_sum']) / (resampled5min2020['Bid Size 1_sum'] + resampled5min2020['Ask Size 1_sum'])

# Level 2
resampled5min2020['Order_Imbalance_2'] = (resampled5min2020['Bid Size 2_sum'] - resampled5min2020['Ask Size 2_sum']) / (resampled5min2020['Bid Size 2_sum'] + resampled5min2020['Ask Size 2_sum'])

# %% [markdown]
# ##### Volume Weighted Average Price (VWAP)

# %%
# Level 1
resampled5min2020['VWAP_1'] = (resampled5min2020['Ask Price 1_last'] * resampled5min2020['Ask Size 1_sum'] + 
                               resampled5min2020['Bid Price 1_last'] * resampled5min2020['Bid Size 1_sum']) / \
                              (resampled5min2020['Ask Size 1_sum'] + resampled5min2020['Bid Size 1_sum'])

# Level 2
resampled5min2020['VWAP_2'] = (resampled5min2020['Ask Price 2_last'] * resampled5min2020['Ask Size 2_sum'] + 
                               resampled5min2020['Bid Price 2_last'] * resampled5min2020['Bid Size 2_sum']) / \
                              (resampled5min2020['Ask Size 2_sum'] + resampled5min2020['Bid Size 2_sum'])

# %%
resampled5min2020.to_csv('resampled_5min_2020_with_features.csv', index=False)
print(resampled5min2020.head())
# Out:
#             Time (sec)  Ask Price 1_first  Ask Price 1_max  Ask Price 1_min  \
# 0  2020-01-02 09:30:00          3235700.0        3238600.0        3234200.0
# 1  2020-01-02 09:35:00          3236800.0        3239800.0        3236600.0
# 2  2020-01-02 09:40:00          3238500.0        3240000.0        3238000.0
# 3  2020-01-02 09:45:00          3238700.0        3240300.0        3237400.0
# 4  2020-01-02 09:50:00          3237500.0        3238600.0        3235800.0
#
#    Ask Price 1_last  Bid Price 1_first  Bid Price 1_max  Bid Price 1_min  \
# 0         3237100.0          3235100.0        3238500.0        3234100.0
# 1         3238500.0          3236700.0        3239600.0        3236500.0
# 2         3238900.0          3238400.0        3239800.0        3237900.0
# 3         3237600.0          3238500.0        3240100.0        3237300.0
# 4         3236300.0          3237400.0        3238500.0        3235700.0
#
#    Bid Price 1_last  Ask Price 2_first  ...  Price_Mean_2_first  \
# ...
