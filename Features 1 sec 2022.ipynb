# %%
import pandas as pd
import os

# %%
data_1sec_2022 = pd.read_csv('final_combined_2022_with_time.csv')

# %%
from IPython.display import display, HTML

html_table = data_1sec_2022.head(10).to_html(index=False)
display(HTML(html_table))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Time (sec)</th>
#       <th>Ask Price 1</th>
#       <th>Ask Size 1</th>
#       <th>Bid Price 1</th>
#       <th>Bid Size 1</th>
#       <th>Ask Price 2</th>
#       <th>Ask Size 2</th>
#       <th>Bid Price 2</th>
#       <th>Bid Size 2</th>
#       <th>Event Type</th>
#       <th>Order ID</th>
#       <th>Size</th>
#       <th>Price</th>
#       <th>Direction</th>
#       <th>Mid_Price_1</th>
#       <th>Mid_Price_2</th>
#       <th>Spread_1</th>
#       <th>Spread_2</th>
#       <th>Volume_Mean_1</th>
#       <th>Volume_Mean_2</th>
#       <th>Order_Imbalance_1</th>
#       <th>Order_Imbalance_2</th>
#       <th>VWAP_1</th>
#       <th>VWAP_2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>2022-01-03 09:30:00</td>
#       <td>4763400.0</td>
#       <td>710.0</td>
#       <td>4763000.0</td>
#       <td>1000.0</td>
#       <td>4763500.0</td>
#       <td>500.0</td>
# ...

# %%
data_1sec_2022['Mid_Price_1'] = (data_1sec_2022['Ask Price 1'] + data_1sec_2022['Bid Price 1']) / 2
data_1sec_2022['Mid_Price_2'] = (data_1sec_2022['Ask Price 2'] + data_1sec_2022['Bid Price 2']) / 2
data_1sec_2022['Spread_1'] = data_1sec_2022['Ask Price 1'] - data_1sec_2022['Bid Price 1']
data_1sec_2022['Spread_2'] = data_1sec_2022['Ask Price 2'] - data_1sec_2022['Bid Price 2']
data_1sec_2022['Volume_Mean_1'] = (data_1sec_2022['Ask Size 1'] + data_1sec_2022['Bid Size 1']) / 2
data_1sec_2022['Volume_Mean_2'] = (data_1sec_2022['Ask Size 2'] + data_1sec_2022['Bid Size 2']) / 2
data_1sec_2022['Order_Imbalance_1'] = (data_1sec_2022['Bid Size 1'] - data_1sec_2022['Ask Size 1']) / (data_1sec_2022['Bid Size 1'] + data_1sec_2022['Ask Size 1'])
data_1sec_2022['Order_Imbalance_2'] = (data_1sec_2022['Bid Size 2'] - data_1sec_2022['Ask Size 2']) / (data_1sec_2022['Bid Size 2'] + data_1sec_2022['Ask Size 2'])
data_1sec_2022['VWAP_1'] = (data_1sec_2022['Ask Price 1'] * data_1sec_2022['Ask Size 1'] + 
                             data_1sec_2022['Bid Price 1'] * data_1sec_2022['Bid Size 1']) / \
                            (data_1sec_2022['Ask Size 1'] + data_1sec_2022['Bid Size 1'])

data_1sec_2022['VWAP_2'] = (data_1sec_2022['Ask Price 2'] * data_1sec_2022['Ask Size 2'] + 
                             data_1sec_2022['Bid Price 2'] * data_1sec_2022['Bid Size 2']) / \
                            (data_1sec_2022['Ask Size 2'] + data_1sec_2022['Bid Size 2'])

# %%
data_1sec_2022.to_csv('data_1sec_2022_with_features.csv', index=False)

# %%
print(data_1sec_2022.head())
# Out:
#             Time (sec)  Ask Price 1  Ask Size 1  Bid Price 1  Bid Size 1  \
# 0  2022-01-03 09:30:00    4763400.0       710.0    4763000.0      1000.0
# 1  2022-01-03 09:30:01    4763500.0       290.0    4763200.0       500.0
# 2  2022-01-03 09:30:02    4763000.0       109.0    4762700.0      2000.0
# 3  2022-01-03 09:30:03    4763300.0       302.0    4763000.0       660.0
# 4  2022-01-03 09:30:04    4763300.0         2.0    4763200.0        17.0
#
#    Ask Price 2  Ask Size 2  Bid Price 2  Bid Size 2  Event Type  ...  \
# 0    4763500.0       500.0    4762800.0       500.0         4.0  ...
# 1    4763600.0       502.0    4763100.0       774.0         4.0  ...
# 2    4763100.0       108.0    4762600.0      1100.0         1.0  ...
# 3    4763400.0       600.0    4762900.0       100.0         3.0  ...
# 4    4763400.0      1646.0    4763100.0         2.0         1.0  ...
#
#    Mid_Price_1  Mid_Price_2  Spread_1  Spread_2  Volume_Mean_1  Volume_Mean_2  \
# ...
